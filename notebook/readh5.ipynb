# %% [markdown]
# Here I read h5 file in dat

# %% [markdown]
# ### read

# %%
import h5py

# %%
f = h5py.File("../data/TUPS_NxN0256_Nl0001_Nf0064_U0020_B05_Gr0001_n0100_pa_U2_new_SDEnew.hdf5","r")

def printname(name):
    print(name)

f.visit(printname)
# Out:
# Chi
# Chi/Final
# Chi/Final/chi_0
# Chi/Final/chi_0_FF
# Chi/Final/chi_0_pp
# Chi/Final/chi_0_pp_FF
# Chi/Final/chi_d
# Chi/Final/chi_m
# Chi/Final/chi_s
# Chi/Final/chi_t
# Chi/chi_0_00000
# Chi/chi_0_00005
# Chi/chi_0_00010
# Chi/chi_0_00015
# Chi/chi_0_00020
# Chi/chi_0_00025
# Chi/chi_0_00030
# Chi/chi_0_00035
# Chi/chi_0_00040
# Chi/chi_0_00045
# Chi/chi_0_00050
# Chi/chi_0_00055
# Chi/chi_0_00060
# Chi/chi_0_00065
# Chi/chi_0_00070
# Chi/chi_0_00075
# Chi/chi_0_00080
# Chi/chi_0_00085
# Chi/chi_0_00090
# Chi/chi_0_00091
# Chi/chi_0_FF_00000
# Chi/chi_0_FF_00005
# Chi/chi_0_FF_00010
# Chi/chi_0_FF_00015
# Chi/chi_0_FF_00020
# Chi/chi_0_FF_00025
# Chi/chi_0_FF_00030
# Chi/chi_0_FF_00035
# Chi/chi_0_FF_00040
# Chi/chi_0_FF_00045
# Chi/chi_0_FF_00050
# Chi/chi_0_FF_00055
# Chi/chi_0_FF_00060
# Chi/chi_0_FF_00065
# Chi/chi_0_FF_00070
# Chi/chi_0_FF_00075
# Chi/chi_0_FF_00080
# Chi/chi_0_FF_00085
# Chi/chi_0_FF_00090
# Chi/chi_0_FF_00091
# Chi/chi_0_pp_00000
# Chi/chi_0_pp_00005
# ...

# %%
list(f.keys())
# Out:
# ['Chi', 'Sigma', 'params']

# %%
params = f["params"]

# %% [markdown]
# ### params

# %%
paramsdict={key:params[key][()] for key in params.keys()}
paramsdict
# Out:
# {'DGA': 0,
#  'Nf': 64,
#  'Ngrain': 1,
#  'Nl': 1,
#  'Nx': 16,
#  'beta': 5.0,
#  'f_range': 0,
#  'nParticle': 1.0,
#  'xU': 2.0}

# %% [markdown]
# ### results

# %%
# 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### sig

# %%
f["Sigma/Final/sig"].shape
# Out:
# (256, 64)

# %%
sig = f["Sigma/Final/sig"][:]

# %%
plt.imshow(sig.real.T)

# %% [markdown]
# #### chi

# %%
list(f["Chi/Final"].keys())
# Out:
# ['chi_0',
#  'chi_0_FF',
#  'chi_0_pp',
#  'chi_0_pp_FF',
#  'chi_d',
#  'chi_m',
#  'chi_s',
#  'chi_t']

# %%
chishape_dict={key: f["Chi/Final"][key].shape for key in f["Chi/Final"].keys()}
chishape_dict
# Out:
# {'chi_0': (256, 32),
#  'chi_0_FF': (4, 256, 32),
#  'chi_0_pp': (256, 32),
#  'chi_0_pp_FF': (4, 256, 32),
#  'chi_d': (4, 256, 32),
#  'chi_m': (4, 256, 32),
#  'chi_s': (4, 256, 32),
#  'chi_t': (4, 256, 32)}

# %%
# 
plt.imshow(f["Chi/Final/chi_0"][:].T.imag)

# %%
# 
plt.imshow(f["Chi/Final/chi_0_pp"][:].T.imag)

# %%
# chi_FF
fig, axs = plt.subplots(4, sharex=True, sharey=True, gridspec_kw={'hspace': 0})
for i in range(4):
    axs[i].imshow(f["Chi/Final/chi_0_FF"][i,:].T.real)
for ax in axs:
    ax.set_aspect('auto')
plt.show()

# %%
# chi_FF
fig, axs = plt.subplots(4, sharex=True, sharey=True, gridspec_kw={'hspace': 0})
for i in range(4):
    axs[i].imshow(f["Chi/Final/chi_0_FF"][i,:].T.imag)
for ax in axs:
    ax.set_aspect('auto')
plt.show()

# %%
# chi_0_pp_FF
fig, axs = plt.subplots(4, sharex=True, sharey=True, gridspec_kw={'hspace': 0})
for i in range(4):
    axs[i].imshow(f["Chi/Final/chi_0_pp_FF"][i,:].T.real)
for ax in axs:
    ax.set_aspect('auto')
plt.show()

# %%
# chi_0_pp_FF
fig, axs = plt.subplots(4, sharex=True, sharey=True, gridspec_kw={'hspace': 0})
for i in range(4):
    axs[i].imshow(f["Chi/Final/chi_0_pp_FF"][i,:].T.imag)
for ax in axs:
    ax.set_aspect('auto')
plt.show()

# %%
fig, axs = plt.subplots(4, sharex=True, sharey=True, gridspec_kw={'hspace': 0})
for i in range(4):
    axs[i].imshow(f["Chi/Final/chi_d"][i,:].T.real)
for ax in axs:
    ax.set_aspect('auto')
plt.show()

# %%
fig, axs = plt.subplots(4, sharex=True, sharey=True, gridspec_kw={'hspace': 0})
for i in range(4):
    axs[i].imshow(f["Chi/Final/chi_d"][i,:].T.imag)
for ax in axs:
    ax.set_aspect('auto')
plt.show()

# %%
fig, axs = plt.subplots(4, sharex=True, sharey=True, gridspec_kw={'hspace': 0})
for i in range(4):
    axs[i].imshow(f["Chi/Final/chi_m"][i,:].T.real)
for ax in axs:
    ax.set_aspect('auto')
plt.show()

# %%
fig, axs = plt.subplots(4, sharex=True, sharey=True, gridspec_kw={'hspace': 0})
for i in range(4):
    axs[i].imshow(f["Chi/Final/chi_m"][i,:].T.imag)
for ax in axs:
    ax.set_aspect('auto')
plt.show()

# %%
fig, axs = plt.subplots(4, sharex=True, sharey=True, gridspec_kw={'hspace': 0})
for i in range(4):
    axs[i].imshow(f["Chi/Final/chi_s"][i,:].T.real)
for ax in axs:
    ax.set_aspect('auto')
plt.show()

# %%
fig, axs = plt.subplots(4, sharex=True, sharey=True, gridspec_kw={'hspace': 0})
for i in range(4):
    axs[i].imshow(f["Chi/Final/chi_s"][i,:].T.imag)
for ax in axs:
    ax.set_aspect('auto')
plt.show()

# %%
fig, axs = plt.subplots(4, sharex=True, sharey=True, gridspec_kw={'hspace': 0})
for i in range(4):
    axs[i].imshow(f["Chi/Final/chi_t"][i,:].T.real)
for ax in axs:
    ax.set_aspect('auto')
plt.show()

# %%
fig, axs = plt.subplots(4, sharex=True, sharey=True, gridspec_kw={'hspace': 0})
for i in range(4):
    axs[i].imshow(f["Chi/Final/chi_t"][i,:].T.imag)
for ax in axs:
    ax.set_aspect('auto')
plt.show()

# %% [markdown]
# ### read scalar

# %%
f = h5py.File("../data/TUPS_NxN0256_Nl0001_Nf0064_U0020_B05_Gr0001_n0100_pa_U2_new_SDEnew.hdf5","r")
dset = f["params/Nf"]
dset[()]
# Out:
# 64
